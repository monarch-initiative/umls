# %%
# %reset -f

# %%
import pandas as pd
from pathlib import Path

# %%
PKG_DIR = Path().cwd().parent

MRCONSO = PKG_DIR / "data/mrconso.tsv"
MRMAP = PKG_DIR / "data/mrmap.tsv"

# %%
mrconso_df = pd.read_csv(MRCONSO, sep="\t")
mrconso_df.head()
# Out:
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_52881/2089181727.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   mrconso_df = pd.read_csv(MRCONSO, sep="\t")
#         CUI  LAT TS       LUI STT        SUI ISPREF        AUI       SAUI  \
# 0  C0000005  ENG  P  L0000005  PF   S0007492      Y  A26634265        NaN
# 1  C0000005  ENG  S  L0270109  PF   S0007491      Y  A26634266        NaN
# 2  C0000039  ENG  P  L0000039  PF  S17175117      N  A28315139  9194921.0
# 3  C0000039  ENG  P  L0000039  PF  S17175117      Y  A28572604        NaN
# 4  C0000039  ENG  P  L0000039  VC   S0007564      Y   A0016515        NaN
#
#        SCUI     SDUI     SAB  TTY     CODE  \
# 0  M0019694  D012711     MSH  PEP  D012711
# 1  M0019694  D012711     MSH   ET  D012711
# 2   1926948      NaN  RXNORM   IN  1926948
# 3       NaN      NaN     MTH   PN   NOCODE
# 4  M0023172  D015060     MSH   MH  D015060
#
# ...

# %%
mrmap_df = pd.read_csv(MRMAP, sep="\t")
mrmap_df.dropna(axis=1, how="all", inplace=True)
mrmap_df.head()
# Out:
# /var/folders/j5/bzs7jjf12j998fm88l0ssg740000gp/T/ipykernel_52881/4206139617.py:1: DtypeWarning: Columns (6,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   mrmap_df = pd.read_csv(MRMAP, sep="\t")
#   MAPSETCUI MAPSETSAB  MAPSUBSETID  MAPRANK        MAPID    FROMID  FROMEXPR  \
# 0  C1306694       MTH          NaN      NaN  AT102971857  C0264643  C0264643
# 1  C1306694       MTH          NaN      NaN  AT102971858  C0276253  C0276253
# 2  C1306694       MTH          NaN      NaN  AT102971859  C0409780  C0409780
# 3  C1306694       MTH          NaN      NaN  AT102971861  C1706094  C1706094
# 4  C1306694       MTH          NaN      NaN  AT102971862  C1706094  C1706094
#
#   FROMTYPE REL RELA  TOID                                             TOEXPR  \
# 0      CUI  SY  NaN  3026  <Hypertension, Renovascular> AND <Hypertension...
# 1      CUI  SY  NaN  4080       <Pneumonia> AND <Cytomegalovirus Infections>
# ...

# %%
mrconso_df[mrconso_df['CUI']=="C1306694"]
# Out:
#               CUI  LAT TS        LUI STT        SUI ISPREF        AUI  SAUI  \
# 1853251  C1306694  ENG  P  L18639429  PF  S22340987      Y  A35395198   NaN
#
#         SCUI SDUI  SAB TTY  CODE                                        STR  \
# 1853251  NaN  NaN  MTH  XM  1000  MSH2023_2023_02_03 Associated Expressions
#
#          SRL SUPPRESS  CVF
# 1853251    0        N  NaN
